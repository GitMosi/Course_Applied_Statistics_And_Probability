# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb

# %%
data = pd.read_csv('C:/Users/Mosi/Python Projects/TA Pythone/Stars/Stars.csv')
data
# Out:
#      Temperature              L          R    A_M  Color Spectral_Class  Type
# 0           3068       0.002400     0.1700  16.12    Red              M     0
# 1           3042       0.000500     0.1542  16.60    Red              M     0
# 2           2600       0.000300     0.1020  18.70    Red              M     0
# 3           2800       0.000200     0.1600  16.65    Red              M     0
# 4           1939       0.000138     0.1030  20.06    Red              M     0
# ..           ...            ...        ...    ...    ...            ...   ...
# 235        38940  374830.000000  1356.0000  -9.93   Blue              O     5
# 236        30839  834042.000000  1194.0000 -10.63   Blue              O     5
# 237         8829  537493.000000  1423.0000 -10.73  White              A     5
# 238         9235  404940.000000  1112.0000 -11.23  White              A     5
# 239        37882  294903.000000  1783.0000  -7.80   Blue              O     5
#
# [240 rows x 7 columns]

# %%
x=np.arange(0,240,1)
t=data['Temperature'].values
l=data['L'].values
r=data['R'].values

# %%
plt.figure(figsize=(9,5),dpi=180)
plt.plot(x,t)
plt.title('Temperature of Stars Plot')
plt.xlabel('Number of Type of Stars')
plt.ylabel('Temperature')
plt.show()

# %%
plt.figure(figsize=(9,5),dpi=180)
plt.hist(t)
plt.title('Histogram of Stars Temperature')
plt.xlabel('Temperature')
plt.ylabel('Count')
plt.grid()
plt.show()

# %%
print('Variance: ',np.var(t),'Standard Deviation: ',np.std(t),'Mean: ',np.mean(t),'Median: ',np.median(t))
# Out:
# Variance:  90868620.65692708 Standard Deviation:  9532.503378280391 Mean:  10497.4625 Median:  5776.0

# %%
plt.figure(figsize=(9,5),dpi=180)
plt.plot(x,l)
plt.title('Luminosity of Stars Plot')
plt.xlabel('Number of Type of Stars')
plt.ylabel('L/L0')
plt.show()

# %%
plt.figure(figsize=(9,5),dpi=180)
plt.hist(l)
plt.title('Histogram of Stars Luminosity')
plt.xlabel('L/L0')
plt.ylabel('Count')
plt.grid()
plt.show()

# %%
print('Variance: ',np.var(l),'Standard Deviation: ',np.std(l),'Mean: ',np.mean(l),'Median: ',np.median(l))
# Out:
# Variance:  32061780813.767277 Standard Deviation:  179058.03755700908 Mean:  107188.36163460833 Median:  0.07050000000000001

# %%
print('Covariance of Luminosity and Temprature: ')
print(np.cov(l,t))
# Out:
# Covariance of Luminosity and Temprature:
# [[3.21959305e+10 6.74299727e+08]
#  [6.74299727e+08 9.12488241e+07]]

# %%
from scipy.stats import pearsonr
p_coeff, p_value=pearsonr(l,t)

# %%
p_coeff #L/L0 ~ T & It has a weak relation.
# Out:
# 0.39340407550976114

# %%
p_value
# Out:
# 2.625357895642515e-10

# %%
c=data['Color'].values
q=np.unique(c)
q
# Out:
# array(['Blue', 'Blue White', 'Blue white', 'Blue-White', 'Blue-white',
#        'Orange', 'Orange-Red', 'Pale yellow orange', 'Red', 'White',
#        'White-Yellow', 'Whitish', 'Yellowish', 'Yellowish White', 'white',
#        'yellow-white', 'yellowish'], dtype=object)

# %%
data=data.replace({'Blue':0, 'Blue White':1, 'Blue white':1, 'Blue-White':1, 'Blue-white':1})
data=data.replace({'Orange':2, 'Orange-Red':3, 'Pale yellow orange':4, 'Red':5, 'White':6})
data=data.replace({'White-Yellow':7, 'Whitish':8, 'Yellowish':9, 'Yellowish White':10, 'white':6})
data=data.replace({'yellow-white':11, 'yellowish':9})

# %%
sp=data['Spectral_Class'].values
qq=np.unique(sp)
qq
# Out:
# array(['A', 'B', 'F', 'G', 'K', 'M', 'O'], dtype=object)

# %%
data=data.replace({'A':0, 'B':1, 'F':2, 'G':3, 'K':4, 'M':5, 'O':6})
data
# Out:
#      Temperature              L          R    A_M  Color  Spectral_Class  Type
# 0           3068       0.002400     0.1700  16.12      5               5     0
# 1           3042       0.000500     0.1542  16.60      5               5     0
# 2           2600       0.000300     0.1020  18.70      5               5     0
# 3           2800       0.000200     0.1600  16.65      5               5     0
# 4           1939       0.000138     0.1030  20.06      5               5     0
# ..           ...            ...        ...    ...    ...             ...   ...
# 235        38940  374830.000000  1356.0000  -9.93      0               6     5
# 236        30839  834042.000000  1194.0000 -10.63      0               6     5
# 237         8829  537493.000000  1423.0000 -10.73      6               0     5
# 238         9235  404940.000000  1112.0000 -11.23      6               0     5
# 239        37882  294903.000000  1783.0000  -7.80      0               6     5
#
# [240 rows x 7 columns]

# %%
c=data['Color'].values
sp=data['Spectral_Class']
from scipy.stats import spearmanr
p_coeff, p_value=spearmanr(c,sp)
p_coeff
# Out:
# -0.17229104222821645

# %%
counter=0
for i in c:
    if i==5:
        counter+=1
    else:
        pass
print('Count of Red Star: ',counter)
# Out:
# Count of Red Star:  112

# %%
plt.figure(figsize=(9,5),dpi=180)
plt.plot(x,r)
plt.title('Radius of Stars Plot')
plt.xlabel('Number of Type of Stars')
plt.ylabel('R/R0')
plt.show()

# %%
plt.figure(figsize=(9,5),dpi=180)
plt.hist(r)
plt.title('Histogram of Stars Radius')
plt.xlabel('R/R0')
plt.ylabel('Count')
plt.grid()
plt.show()

# %%
print('Variance: ',np.var(r),'Standard Deviation: ',np.std(r),'Mean: ',np.mean(r),'Median: ',np.median(r))
# Out:
# Variance:  266335.7082723624 Standard Deviation:  516.0772309183601 Mean:  237.157781375 Median:  0.7625

# %%
corr=data.corr()
corr
# Out:
#                 Temperature         L         R       A_M     Color  \
# Temperature        1.000000  0.393404  0.064216 -0.420261 -0.675345
# L                  0.393404  1.000000  0.526516 -0.692619 -0.366836
# R                  0.064216  0.526516  1.000000 -0.608728 -0.032348
# A_M               -0.420261 -0.692619 -0.608728  1.000000  0.344999
# Color             -0.675345 -0.366836 -0.032348  0.344999  1.000000
# Spectral_Class    -0.207852  0.275280  0.097124 -0.085840  0.075775
# Type               0.411129  0.676845  0.660975 -0.955276 -0.309030
#
#                 Spectral_Class      Type
# Temperature          -0.207852  0.411129
# L                     0.275280  0.676845
# R                     0.097124  0.660975
# A_M                  -0.085840 -0.955276
# Color                 0.075775 -0.309030
# Spectral_Class        1.000000 -0.049131
# Type                 -0.049131  1.000000

# %%
plt.figure(figsize=(7,5),dpi=160)
heatmap=sb.heatmap(corr,vmin=-1,vmax=1)
plt.title('Correlation of Stars Dataset')
plt.xlabel('Feture Names')
plt.ylabel('Feture Names')
heatmap
plt.show()
