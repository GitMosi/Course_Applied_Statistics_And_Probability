# %%
import math 
import numpy as np 
import matplotlib.pyplot as plt
from math import factorial as fa
def psy(x):
    s=0
    pi=math.pi
    b=math.sqrt(2)/math.sqrt(a)
    s=b*np.sin(pi*float(n)*x/float(a))
    return s

n=float(input("Enter your number for n: "))
a=float(input("Enter your number for a: "))
x=np.linspace(0,a,85)
plt.figure(figsize=(9,5),dpi=180)
plt.plot(x,psy(x))
plt.scatter(x,psy(x))
plt.xlabel('x')
plt.ylabel('Psy(x)')
plt.title('Sine Taylor Series Plotting')
plt.show()

print("...Try Again!")
# Out:
# Enter your number for n: 1
# Enter your number for a: 2
# ...Try Again!
