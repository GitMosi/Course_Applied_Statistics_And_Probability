# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb

# %%
data = pd.read_csv('C:/Users/Mosi/Python Projects/TA Pythone/BTC/BTC.csv')
data
# Out:
#             date     1. open     2. high      3. low    4. close  5. volume
# 0      8/19/2011     10.9000     10.9000     10.9000     10.9000          0
# 1      8/20/2011     11.8500     11.8500     11.1500     11.6900          1
# 2      8/21/2011     11.7000     11.7000     11.7000     11.7000          0
# 3      8/22/2011     11.7000     11.7000     11.7000     11.7000          0
# 4      8/23/2011     11.7000     11.7000     11.7000     11.7000          0
# ...          ...         ...         ...         ...         ...        ...
# 3700   11/7/2021  61486.5858  63293.6064  61345.1077  63280.0615      34366
# 3701   11/8/2021  63283.3131  67772.6291  63283.3068  67532.2386      65777
# 3702   11/9/2021  67531.9826  68522.0065  66326.9613  66942.3801      52140
# 3703  11/10/2021  66944.8576  68990.6665  63319.6921  64897.4985      61210
# 3704  11/11/2021  64891.1375  65596.8454  64098.4651  64785.3826      47337
#
# [3705 rows x 6 columns]

# %%
x=np.arange(0,3705,1)
d=data['date'].values
o=data['1. open'].values
h=data['2. high'].values
l=data['3. low'].values
c=data['4. close'].values
v=data['5. volume'].values

# %%
plt.figure(figsize=(9,5),dpi=180)
plt.plot(x,o)
plt.title('BTC Open Prices Plot')
plt.xlabel('Number of Day')
plt.ylabel('Open Price')
plt.show()

# %%
plt.figure(figsize=(9,5),dpi=180)
plt.hist(o)
plt.title('Histogram of BTC Open Prices')
plt.xlabel('Open Price')
plt.ylabel('Count')
plt.grid()
plt.show()

# %%
print('Variance: ',np.var(o),'Standard Deviation ',np.std(o),'Mean: ',np.mean(o),'Median: ',np.median(o))
# Out:
# Variance:  171094150.5470501 Standard Deviation  13080.296271378951 Mean:  7049.665296842106 Median:  774.698

# %%
plt.figure(figsize=(9,5),dpi=180)
plt.plot(x,h)
plt.title('BTC Highest Prices Plot')
plt.xlabel('Number of Day')
plt.ylabel('Highest Price')
plt.show()

# %%
plt.figure(figsize=(9,5),dpi=180)
plt.hist(h)
plt.title('Histogram of BTC Highest Prices')
plt.xlabel('Highest Price')
plt.ylabel('Count')
plt.grid()
plt.show()

# %%
print('Variance: ',np.var(h),'Standard Deviation ',np.std(h),'Mean: ',np.mean(h),'Median: ',np.median(h))
# Out:
# Variance:  181879009.69361302 Standard Deviation  13486.252618634022 Mean:  7283.503126936572 Median:  793.27

# %%
plt.figure(figsize=(9,5),dpi=180)
plt.plot(x,l)
plt.title('BTC Lowest Prices Plot')
plt.xlabel('Number of Day')
plt.ylabel('Lowest Price')
plt.show()

# %%
plt.figure(figsize=(9,5),dpi=180)
plt.hist(l)
plt.title('Histogram of BTC Lowest Prices')
plt.xlabel('Lowest Price')
plt.ylabel('Count')
plt.grid()
plt.show()

# %%
print('Variance: ',np.var(l),'Standard Deviation ',np.std(l),'Mean: ',np.mean(l),'Median: ',np.median(l))
# Out:
# Variance:  159899755.00695997 Standard Deviation  12645.147488541206 Mean:  6790.861537327935 Median:  751.34

# %%
plt.figure(figsize=(9,5),dpi=180)
plt.plot(x,c)
plt.title('BTC Close Prices Plot')
plt.xlabel('Number of Day')
plt.ylabel('Close Price')
plt.show()

# %%
plt.figure(figsize=(9,5),dpi=180)
plt.hist(c)
plt.title('Histogram of BTC Close Prices')
plt.xlabel('Close Price')
plt.ylabel('Count')
plt.grid()
plt.show()

# %%
print('Variance: ',np.var(c),'Standard Deviation ',np.std(c),'Mean: ',np.mean(c),'Median: ',np.median(c))
# Out:
# Variance:  172021062.8758382 Standard Deviation  13115.680038634604 Mean:  7064.862752739541 Median:  772.28

# %%
plt.figure(figsize=(9,5),dpi=180)
plt.plot(x,v)
plt.title('BTC Traded Volumes Plot')
plt.xlabel('Number of Day')
plt.ylabel('Traded Volume')
plt.show()

# %%
plt.figure(figsize=(9,5),dpi=180)
plt.hist(c)
plt.title('Histogram of BTC Traded Volumes')
plt.xlabel('Traded Volume')
plt.ylabel('Count')
plt.grid()
plt.show()

# %%
print('Variance: ',np.var(v),'Standard Deviation ',np.std(v),'Mean: ',np.mean(v),'Median: ',np.median(v))
# Out:
# Variance:  2445374370.827218 Standard Deviation  49450.7266966545 Mean:  40816.728475033735 Median:  20700.0

# %%
print('Covariance of Close Price and Volume: ')
print(np.cov(c,v))
# Out:
# Covariance of Close Price and Volume:
# [[1.72067505e+08 3.15217371e+08]
#  [3.15217371e+08 2.44603457e+09]]

# %%
from scipy.stats import pearsonr
p_coeff, p_value=pearsonr(c,v)

# %%
p_coeff
# Out:
# 0.48588044138422987

# %%
corr=data.corr()
corr
# Out:
#             1. open   2. high    3. low  4. close  5. volume
# 1. open    1.000000  0.999511  0.999158  0.999026   0.487242
# 2. high    0.999511  1.000000  0.998952  0.999530   0.492764
# 3. low     0.999158  0.998952  1.000000  0.999371   0.477624
# 4. close   0.999026  0.999530  0.999371  1.000000   0.485880
# 5. volume  0.487242  0.492764  0.477624  0.485880   1.000000

# %%
plt.figure(figsize=(7,5),dpi=160)
heatmap=sb.heatmap(corr,vmin=-1,vmax=1)
plt.title('Correlation of BTC Dataset')
plt.xlabel('Feture Names')
plt.ylabel('Feture Names')
heatmap
plt.show()
